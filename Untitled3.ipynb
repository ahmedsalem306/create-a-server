# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedsalem306/create-a-server/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls /content/drive/MyDrive
# Out:
# 'assignment 3.rar'
# 'Colab Notebooks'
# 'Coursera 2KFUCP3LTUYX.pdf'
# 'Coursera 4R4R882ZBHL8 (1).pdf'
# 'Coursera 4R4R882ZBHL8 (2).pdf'
# 'Coursera 4R4R882ZBHL8.pdf'
# 'Coursera 6PZ8EHEWRVE2.pdf'
# 'Coursera R627PEPQBHWT.pdf'
# 'Google AI Studio'
#  hymenoptera_data
# 'Natural Language Processing.docx'
#  photo_2022-09-06_18-20-56.gdoc
#  photo_2022-09-06_18-20-56.jpg
#  photo_2022-09-06_18-20-57.jpg
#  photo_2022-09-06_18-20-58.jpg
#  photo_2022-09-06_18-20-59.jpg
#  photo_2022-09-06_18-21-01.jpg
#  photo_2022-09-06_18-21-02.jpg
#  photo_2022-09-06_18-21-11.jpg
#  photo_2022-09-06_18-21-19.jpg
#  photo_2022-09-06_18-21-51.jpg
#  photo_2022-09-06_18-21-52.jpg
#  photo_2022-09-06_18-21-54.jpg
#  photo_2022-09-06_18-21-55.jpg
#  photo_2022-09-06_18-21-56.jpg
#  photo_2022-09-06_18-21-57.jpg
# 'photo_2022-09-06_18-21-58 (2).jpg'
#  photo_2022-09-06_18-21-58.jpg
#  photo_2022-09-06_18-21-59.jpg
#  photo_2022-09-06_18-22-00.jpg
#  photo_2022-09-06_18-22-01.jpg
#  photo_2022-09-06_18-22-03.jpg
#  photo_2022-09-06_18-22-11.jpg
#  photo_2022-09-06_18-22-14.jpg
#  photo_2022-09-06_18-22-16.jpg
#  photo_2022-09-06_18-22-19.jpg
#  photo_2022-09-06_18-22-22.jpg
#  photo_2022-09-06_18-22-23.jpg
#  photo_2022-09-06_18-22-24.jpg
#  photo_2022-09-06_18-22-26.jpg
#  photo_2022-09-06_18-23-40.jpg
# 'Screenshot 2023-02-26 171049.png'
# 'WhatsApp Image 2023-03-21 at 6.11.20 PM.gdoc'
# 'WhatsApp Image 2023-03-21 at 6.11.20 PM.jpeg'
# 'شهادات it.pdf'

# %%
# !ls /content/drive/MyDrive/hymenoptera_data
# Out:
# train  val

# %%
# !ls /content/drive/MyDrive/hymenoptera_data/ants_bees
# Out:
# ls: cannot access '/content/drive/MyDrive/hymenoptera_data/ants_bees': No such file or directory

# %%
data_dir = "/content/drive/MyDrive/CNN_Assignment/ants_bees"

# %%
# !ls /content/drive/MyDrive/CNN_Assignment/ants_bees/train
# Out:
# ls: cannot access '/content/drive/MyDrive/CNN_Assignment/ants_bees/train': No such file or directory

# %%
# !find /content/drive/MyDrive -type d -name "ants" -o -name "bees"
# Out:
# /content/drive/MyDrive/CNN_Assignment/val/bees
# /content/drive/MyDrive/CNN_Assignment/val/ants
# /content/drive/MyDrive/CNN_Assignment/train/bees
# /content/drive/MyDrive/CNN_Assignment/train/ants

# %%
data_dir = "/content/drive/MyDrive/CNN_Assignment"

# %%
# !ls /content/drive/MyDrive/CNN_Assignment/train
# Out:
# ants  bees

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Out:
# Using device: cuda

# %%
data_dir = "/content/drive/MyDrive/CNN_Assignment"

transform_train = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

transform_val = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

train_data = datasets.ImageFolder(os.path.join(data_dir, 'train'), transform=transform_train)
val_data = datasets.ImageFolder(os.path.join(data_dir, 'val'), transform=transform_val)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)

class_names = train_data.classes

# %%
class SimpleCNN_Updated(nn.Module):
    def __init__(self):
        super(SimpleCNN_Updated, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(16, 32, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(), nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 8 * 8, 128), nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, 2)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
class DeeperCNN_Updated(nn.Module):
    def __init__(self):
        super(DeeperCNN_Updated, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1), nn.BatchNorm2d(16), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(16, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(256, 512, 3, padding=1), nn.BatchNorm2d(512), nn.ReLU(), nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512 * 2 * 2, 256), nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 2)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
def train_model(model, train_loader, val_loader, num_epochs=30):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    train_loss, val_loss = [], []
    train_acc, val_acc = [], []

    for epoch in range(num_epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        train_loss.append(running_loss / len(train_loader))
        train_acc.append(100. * correct / total)

        model.eval()
        val_running_loss, val_correct, val_total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_loss.append(val_running_loss / len(val_loader))
        val_acc.append(100. * val_correct / val_total)

        print(f"Epoch {epoch+1}/{num_epochs} => Train Acc: {train_acc[-1]:.2f}% | Val Acc: {val_acc[-1]:.2f}%")

    return train_loss, val_loss, train_acc, val_acc, model

# %%
def plot_metrics(train_loss, val_loss, train_acc, val_acc, title='Model'):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Val Loss')
    plt.legend()
    plt.title(f'{title} - Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Acc')
    plt.plot(val_acc, label='Val Acc')
    plt.legend()
    plt.title(f'{title} - Accuracy')

    plt.show()

# %%
def plot_metrics(train_loss, val_loss, train_acc, val_acc, title='Model'):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Val Loss')
    plt.legend()
    plt.title(f'{title} - Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Acc')
    plt.plot(val_acc, label='Val Acc')
    plt.legend()
    plt.title(f'{title} - Accuracy')

    plt.show()

def show_confusion_matrix(model, loader, title="Confusion Matrix"):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap='Blues')
    plt.title(title)
    plt.show()

# %%
print("Training Updated Model A...")
model_a = SimpleCNN_Updated()
train_loss_a, val_loss_a, train_acc_a, val_acc_a, model_a = train_model(model_a, train_loader, val_loader)

print("Training Updated Model B...")
model_b = DeeperCNN_Updated()
train_loss_b, val_loss_b, train_acc_b, val_acc_b, model_b = train_model(model_b, train_loader, val_loader)

plot_metrics(train_loss_a, val_loss_a, train_acc_a, val_acc_a, title="Model A (Updated)")
show_confusion_matrix(model_a, val_loader, title="Model A")

plot_metrics(train_loss_b, val_loss_b, train_acc_b, val_acc_b, title="Model B (Updated)")
show_confusion_matrix(model_b, val_loader, title="Model B")
# Out:
# Training Updated Model A...
# Epoch 1/30 => Train Acc: 56.97% | Val Acc: 54.25%
# Epoch 2/30 => Train Acc: 57.38% | Val Acc: 52.94%
# Epoch 3/30 => Train Acc: 57.79% | Val Acc: 56.86%
# Epoch 4/30 => Train Acc: 66.80% | Val Acc: 67.97%
# Epoch 5/30 => Train Acc: 66.80% | Val Acc: 64.05%
# Epoch 6/30 => Train Acc: 64.34% | Val Acc: 54.25%
# Epoch 7/30 => Train Acc: 71.72% | Val Acc: 67.32%
# Epoch 8/30 => Train Acc: 70.90% | Val Acc: 66.67%
# Epoch 9/30 => Train Acc: 74.59% | Val Acc: 65.36%
# Epoch 10/30 => Train Acc: 73.77% | Val Acc: 70.59%
# Epoch 11/30 => Train Acc: 73.36% | Val Acc: 73.86%
# Epoch 12/30 => Train Acc: 73.36% | Val Acc: 63.40%
# Epoch 13/30 => Train Acc: 77.05% | Val Acc: 71.90%
# Epoch 14/30 => Train Acc: 77.46% | Val Acc: 71.24%
# Epoch 15/30 => Train Acc: 76.23% | Val Acc: 62.09%
# Epoch 16/30 => Train Acc: 75.00% | Val Acc: 67.32%
# Epoch 17/30 => Train Acc: 75.00% | Val Acc: 68.63%
# Epoch 18/30 => Train Acc: 81.15% | Val Acc: 71.24%
# Epoch 19/30 => Train Acc: 76.64% | Val Acc: 72.55%
# Epoch 20/30 => Train Acc: 78.28% | Val Acc: 71.90%
# Epoch 21/30 => Train Acc: 81.97% | Val Acc: 69.93%
# Epoch 22/30 => Train Acc: 81.56% | Val Acc: 71.24%
# Epoch 23/30 => Train Acc: 81.97% | Val Acc: 70.59%
# Epoch 24/30 => Train Acc: 84.84% | Val Acc: 70.59%
# Epoch 25/30 => Train Acc: 84.02% | Val Acc: 71.24%
# Epoch 26/30 => Train Acc: 84.84% | Val Acc: 69.93%
# Epoch 27/30 => Train Acc: 86.48% | Val Acc: 69.28%
# Epoch 28/30 => Train Acc: 85.25% | Val Acc: 67.32%
# Epoch 29/30 => Train Acc: 87.70% | Val Acc: 67.97%
# Epoch 30/30 => Train Acc: 87.30% | Val Acc: 65.36%
# Training Updated Model B...
# Epoch 1/30 => Train Acc: 55.74% | Val Acc: 45.75%
# Epoch 2/30 => Train Acc: 59.84% | Val Acc: 45.75%
# Epoch 3/30 => Train Acc: 61.48% | Val Acc: 45.75%
# Epoch 4/30 => Train Acc: 64.75% | Val Acc: 47.71%
# Epoch 5/30 => Train Acc: 70.90% | Val Acc: 71.24%
# Epoch 6/30 => Train Acc: 68.85% | Val Acc: 67.32%
# Epoch 7/30 => Train Acc: 72.95% | Val Acc: 71.90%
# Epoch 8/30 => Train Acc: 72.54% | Val Acc: 74.51%
# Epoch 9/30 => Train Acc: 69.67% | Val Acc: 61.44%
# Epoch 10/30 => Train Acc: 74.18% | Val Acc: 66.01%
# Epoch 11/30 => Train Acc: 76.64% | Val Acc: 72.55%
# Epoch 12/30 => Train Acc: 79.10% | Val Acc: 71.90%
# Epoch 13/30 => Train Acc: 77.87% | Val Acc: 70.59%
# Epoch 14/30 => Train Acc: 81.97% | Val Acc: 73.86%
# Epoch 15/30 => Train Acc: 80.74% | Val Acc: 75.16%
# Epoch 16/30 => Train Acc: 81.97% | Val Acc: 69.28%
# Epoch 17/30 => Train Acc: 84.84% | Val Acc: 71.90%
# Epoch 18/30 => Train Acc: 81.97% | Val Acc: 73.86%
# Epoch 19/30 => Train Acc: 87.30% | Val Acc: 69.93%
# Epoch 20/30 => Train Acc: 86.07% | Val Acc: 71.24%
# Epoch 21/30 => Train Acc: 88.52% | Val Acc: 69.28%
# Epoch 22/30 => Train Acc: 92.21% | Val Acc: 73.86%
# Epoch 23/30 => Train Acc: 88.93% | Val Acc: 73.86%
# Epoch 24/30 => Train Acc: 90.16% | Val Acc: 60.78%
# Epoch 25/30 => Train Acc: 90.57% | Val Acc: 75.82%
# Epoch 26/30 => Train Acc: 92.21% | Val Acc: 71.90%
# Epoch 27/30 => Train Acc: 92.62% | Val Acc: 66.01%
# Epoch 28/30 => Train Acc: 95.08% | Val Acc: 72.55%
# Epoch 29/30 => Train Acc: 91.80% | Val Acc: 67.97%
# Epoch 30/30 => Train Acc: 93.85% | Val Acc: 66.01%
